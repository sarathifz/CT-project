# %%
import os
import pandas as pd

# %%
folder_path = 'C:/Users/DineshMohan/Desktop/dataSets'
dfs = []

# %%
# Loop through each file in the directory
for filename in os.listdir(folder_path):
    if filename.endswith('.csv'):
        # Construct the full file path
        file_path = os.path.join(folder_path, filename)
        
        # Read the CSV file into a DataFrame and append to the list
        df = pd.read_csv(file_path,encoding='latin1')
        dfs.append(df)

# Concatenate all DataFrames into a single DataFrame
combined_df = pd.concat(dfs, ignore_index=True)

# %%
df = combined_df

# %%
df
# Out:
#        State Code District Code                India/States Division Group  \
# 0             `07          `000        STATE - NCT OF DELHI      `00  `000
# 1             `07          `000        STATE - NCT OF DELHI      `01  `000
# 2             `07          `000        STATE - NCT OF DELHI      `01  `011
# 3             `07          `000        STATE - NCT OF DELHI      `01  `011
# 4             `07          `000        STATE - NCT OF DELHI      `01  `011
# ...           ...           ...                         ...      ...   ...
# 195140        `19          `345  District - Purba Medinipur      `99  `990
# 195141        `19          `345  District - Purba Medinipur      `99  `991
# 195142        `19          `345  District - Purba Medinipur      `99  `991
# 195143        `19          `345  District - Purba Medinipur      `99  `992
# 195144        `19          `345  District - Purba Medinipur      `99  `992
#
#         Class                                           NIC Name  \
# ...

# %%
# for i in df:
#     i = i[]
#     print(i)

# %%
# df['State Code'] = df['State Code'].str.replace('`','')

# %%
df
# Out:
#        State Code District Code                India/States Division Group  \
# 0             `07          `000        STATE - NCT OF DELHI      `00  `000
# 1             `07          `000        STATE - NCT OF DELHI      `01  `000
# 2             `07          `000        STATE - NCT OF DELHI      `01  `011
# 3             `07          `000        STATE - NCT OF DELHI      `01  `011
# 4             `07          `000        STATE - NCT OF DELHI      `01  `011
# ...           ...           ...                         ...      ...   ...
# 195140        `19          `345  District - Purba Medinipur      `99  `990
# 195141        `19          `345  District - Purba Medinipur      `99  `991
# 195142        `19          `345  District - Purba Medinipur      `99  `991
# 195143        `19          `345  District - Purba Medinipur      `99  `992
# 195144        `19          `345  District - Purba Medinipur      `99  `992
#
#         Class                                           NIC Name  \
# ...

# %%
Don = lambda x: x.replace('`','').replace('/',' ')

# %%
rep = lambda x: x.replace('`','')

# %%
df['State Code'] = df['State Code'].apply(rep)

# %%
df
# Out:
#        State Code District Code                India/States Division Group  \
# 0              07          `000        STATE - NCT OF DELHI      `00  `000
# 1              07          `000        STATE - NCT OF DELHI      `01  `000
# 2              07          `000        STATE - NCT OF DELHI      `01  `011
# 3              07          `000        STATE - NCT OF DELHI      `01  `011
# 4              07          `000        STATE - NCT OF DELHI      `01  `011
# ...           ...           ...                         ...      ...   ...
# 195140         19          `345  District - Purba Medinipur      `99  `990
# 195141         19          `345  District - Purba Medinipur      `99  `991
# 195142         19          `345  District - Purba Medinipur      `99  `991
# 195143         19          `345  District - Purba Medinipur      `99  `992
# 195144         19          `345  District - Purba Medinipur      `99  `992
#
#         Class                                           NIC Name  \
# ...

# %%
df['NIC Name']
# Out:
# 0                                                     Total
# 1         Crop and animal production, hunting and relate...
# 2                            Growing of non-perennial crops
# 3         Growing of cereals (except rice), leguminous c...
# 4                                           Growing of rice
#                                 ...
# 195140    Activities of extraterritorial organizations a...
# 195141                                                Blank
# 195142                                                Blank
# 195143            Incomplete description/ Wrongly Classifed
# 195144            Incomplete description/ Wrongly Classifed
# Name: NIC Name, Length: 195145, dtype: object

# %%
data = {'A': [1, 2, 3, 4, 5],
        'B': ['`01', '02', '`03', '04', '`05'],
        'C':['a/b','c/d','e/f','g/h','i/j']
        }

# data = pd.DataFrame(data)

# Don = lambda x: x.replace('`','').replace('/',' ')
# data['B'] = data['B'].apply(Don)

# print(data)
# Out:
# <function print(*args, sep=' ', end='\n', file=None, flush=False)>

# %%
# data = pd.DataFrame(data)

# %%
data['B'] = data['B'].apply(Don)

# %%
data
# Out:
#    A   B    C
# 0  1  01  a/b
# 1  2  02  c/d
# 2  3  03  e/f
# 3  4  04  g/h
# 4  5  05  i/j

# %%
add = lambda x:x+2

# %%
a = 2

# %%
add(a)
# Out:
# 4

# %%
data['B']
# Out:
# 0     c1
# 1     c2
# 2     c3
# 3     c4
# 4     c5
# Name: B, dtype: object

# %%
a
# Out:
# 2

# %%
import pandas as pd

# Create a dataframe
df = pd.DataFrame({'text': ['This is a sentence.', 'This is another sentence.']})

# Define a function to tokenize the text
def tokenize(text):
    return text.split()

# Apply the tokenize() function to each row of the dataframe
df['tokens'] = df['text'].apply(tokenize)

# Print the dataframe
print(df)
# Out:
#                         text                          tokens
# 0        This is a sentence.        [This, is, a, sentence.]
# 1  This is another sentence.  [This, is, another, sentence.]

# %%
pip install --upgrade pip
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd
import nltk
from nltk.tokenize import word_tokenize

# Sample data
data = {'A': [1, 2, 3, 4, 5],
        'B': ['01', '02', '03', '04', '05']}

# Convert the dictionary to a DataFrame
df = pd.DataFrame(data)

# Function to tokenize text using NLTK
def tokenize_text(text):
    return word_tokenize(text)

# Apply tokenization to column 'B'
df['B_tokenized'] = df['B'].apply(tokenize_text)

print(df)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# Cell In[37], line 17
#      14     return word_tokenize(text)
#      16 # Apply tokenization to column 'B'
# ---> 17 df['B_tokenized'] = df['B'].apply(tokenize_text)
#      19 print(df)
#
# File ~\AppData\Local\Packages\PythonSoftwareFoundation.Python.3.11_qbz5n2kfra8p0\LocalCache\local-packages\Python311\site-packages\pandas\core\series.py:4760, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4625 def apply(
#    4626     self,
#    4627     func: AggFuncType,
#    (...)
#    4632     **kwargs,
#    4633 ) -> DataFrame | Series:
#    4634     """
#    4635     Invoke function on values of Series.
#    4636
#    (...)
#    4751     dtype: float64
#    4752     """
#    4753     return SeriesApply(
#    4754         self,
#    4755         func,
#    4756         convert_dtype=convert_dtype,
# ...

# %%
import pandas as pd
import re

data = {'A': [1, 2, 3, 4, 5],
        'B': ['#0', '&99', '66', '33', '77']}

df = pd.DataFrame(data)

# Extract numerical values from strings using regular expressions
df['B_numerical'] = df['B'].apply(lambda x: int(re.search(r'\d+', x).group()))

print(df)
# Out:
#    A    B  B_numerical
# 0  1   #0            0
# 1  2  &99           99
# 2  3   66           66
# 3  4   33           33
# 4  5   77           77

# %%
import re

def extract_numbers(text):
    numbers = re.findall(r'\d+', text)
    return numbers

def main():
    text = "I have 10 apples and 20 oranges."
    numbers = extract_numbers(text)
    print("Numbers found in the text:", numbers)

if __name__ == "__main__":
    main()
# Out:
# Numbers found in the text: ['10', '20']

# %%
a= map(int,input().split())

# %%
a

# %%
# Define a list of strings
words = ['hello', 'world', 'python', 'programming']

word = 'partha'

# # Use the map function to apply the str.upper function to each string in the list
# uppercase_words = list(map(str.upper, words))

# # Print the original and uppercase lists
# print("Original words:", words)
# print("Uppercase words:", uppercase_words)

# lowercase_words = list(map(str.lower, words))

# print("Original words:", words)
# print("lowercase words:", lowercase_words)

# %%
upper = str.upper(words)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[57], line 1
# ----> 1 upper = str.upper(words)
#
# TypeError: descriptor 'upper' for 'str' objects doesn't apply to a 'list' object

# %%
upper = words.str.upper
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[55], line 1
# ----> 1 upper = words.str.upper
#
# AttributeError: 'list' object has no attribute 'str'

# %%
upper = str.upper(word)
upper
# Out:
# 'PARTHA'
